# %% [markdown]
# ## Question (Email Records)

# %%
import json
def validEmail():
    
    
    data={
              
        "problem": "Prepare a clean list of unique user emails.",
        "data": {
            
            "emails": [
                              
                 " Admin@Gmail.com ",
                 "user@yahoo.com",
                 "admin@gmail.com",
                 "USER@yahoo.com",
                 "test@outlook.com",
                 "",
                 null,
                 "test@OUTLOOK.com "
                
                 ]
            }
        }
    
    file=json.loads(data)
    return print(file)
validEmail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      25     file=json.loads(data)
#      26     return print(file)
# ---> 27 validEmail()
#
# Cell In[1], line 18, in validEmail()
#       2 def validEmail():
#       5     data={
#       6
#       7         "problem": "Prepare a clean list of unique user emails.",
#       8         "data": {
#       9
#      10             "emails": [
#      11
#      12                  " Admin@Gmail.com ",
#      13                  "user@yahoo.com",
#      14                  "admin@gmail.com",
#      15                  "USER@yahoo.com",
#      16                  "test@outlook.com",
#      17                  "",
# ---> 18                  null,
#      19                  "test@OUTLOOK.com "
#      20
#      21                  ]
#      22             }
#      23         }
#      25     file=json.loads(data)
# ...
