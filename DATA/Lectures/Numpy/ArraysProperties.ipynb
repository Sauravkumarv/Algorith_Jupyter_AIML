# %% [markdown]
# # Arrays Properties

# %%
import numpy as np
arr=np.array([[1,4,5],[7,8,4],[8,9,4]])
print(arr.shape)
# Out:
# (3, 3)

# %%
print(arr.size)
# Out:
# 9

# %%
print(arr.dtype)
# Out:
# int64

# %%
print(arr.ndim)
# Out:
# 2

# %%
float_arr=arr.astype(np.float64)
print(float_arr,float_arr.dtype)
# Out:
# [[1. 4. 5.]
#  [7. 8. 4.]
#  [8. 9. 4.]] float64
