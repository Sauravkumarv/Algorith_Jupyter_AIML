# %% [markdown]
# ## Python List To ndArray

# %%
import numpy as np
py_list=list([1,2,3,4,5])
print(f"{py_list} {type(py_list)}")
py_arr=np.array(py_list)
print(f"{py_arr} {type(py_arr)}")
# Out:
# [1, 2, 3, 4, 5] <class 'list'>
# [1 2 3 4 5] <class 'numpy.ndarray'>
