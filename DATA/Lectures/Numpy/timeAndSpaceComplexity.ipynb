# %%
import numpy as np
import time
import sys
size=100_000_000
py_list=list(range(size))
start=time.time()
cal_sq=[a**2 for a in py_list]
end=time.time()

print(f"Python List time={end-start} seconds")

numpy_arr=np.array(py_list)
start1=time.time()
cal_sq=numpy_arr**2   #Vectorization
end1=time.time()

print(f"Numpy Array time={end1-start1} seconds")
# Out:
# Python List time=40.11442685127258 seconds
# Numpy Array time=20.83362650871277 seconds

# %% [markdown]
# # Memory Comparison

# %%
print(f"Python List size={sys.getsizeof(py_list)*len(py_list)}bytes")
print(f"Numpy Array List size={numpy_arr.nbytes}bytes")
# Out:
# Python List size=80000005600000000bytes
# Numpy Array List size=800000000bytes
