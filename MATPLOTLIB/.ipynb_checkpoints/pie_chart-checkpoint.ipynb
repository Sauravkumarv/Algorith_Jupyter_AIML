# %% [markdown]
# # Practising Pie Chart

# %%
import matplotlib.pyplot as plt
labels = ["Rent", "Food", "Transport", "Shopping", "Savings"]
values = [40, 20, 10, 15, 15]
plt.title("Monthly Expenses")
plt.pie(values,labels=labels,autopct="%1.1f%%",radius=1)
plt.legend()
