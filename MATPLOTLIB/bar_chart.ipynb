# %% [markdown]
# # Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np
cities = ["Delhi", "Mumbai", "Bangalore", "Chennai"]

male_population   = [9.8, 7.5, 6.2, 4.3]
female_population = [8.9, 7.0, 5.8, 4.0]
x=np.arange(len(cities))

width=0.4
plt.bar(x-width/2,male_population,width, label="Male")
plt.bar(x+width/2,female_population,width, label="Female")
plt.title("Population in popular cities")
plt.xlabel("Cities")
plt.ylabel("Population in (cr)")
plt.legend()
plt.xticks(x,cities)

for m in range(len(male_population)):
    plt.text(
        x[m],
        male_population[m]+0.1,
        male_population[m],
        ha='center',
            )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 19
#      16 plt.xticks(x,cities)
#      18 for m in range(len(male_population)):
# ---> 19     plt.text(
#      20         x[m],
#      21         x-width/2,male_population[m]+0.1,
#      22         x-width/2,male_population[m],
#      23         ha='center',
#      24             )
#
# TypeError: text() takes from 3 to 4 positional arguments but 5 were given
