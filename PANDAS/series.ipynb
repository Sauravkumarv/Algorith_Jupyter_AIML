# %% [markdown]
# # Series ( Methods & Formula )

# %%
import pandas as pd

arr=pd.Series([1,4,5,8],index=["Adam", "Eve", "Charlie", "Bob"])
print(arr) 
arr[3] #Indexing
arr[2:] #SLicing
arr.index
df
# Out:
# Adam       1
# Eve        4
# Charlie    5
# Bob        8
# dtype: int64
# C:\Users\Suraj Verma\AppData\Local\Temp\ipykernel_13228\270021079.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   arr[3] #Indexing
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       6 arr[2:] #SLicing
#       7 arr.index
# ----> 8 df
#
# NameError: name 'df' is not defined

# %%
arr=pd.read_csv("global_air_quality.csv")
print(arr)

# %%
s1=pd.Series([1,2,3])
s2=pd.Series([4,5,6])
print(s1+s2)
s1[0]=8
print(s1)
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64
# 0    8
# 1    2
# 2    3
# dtype: int64
