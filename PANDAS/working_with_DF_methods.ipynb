# %% [markdown]
# # Working with Data Frames methods

# %%
import pandas as pd
file=pd.read_csv("globalAirquality.csv")
file
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %% [markdown]
# # Methods

# %%
file.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
file.tail()
# Out:
#                         timestamp country    city  latitude  longitude  \
# 17995  2025-11-19 13:25:17.554219      CH  Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH  Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH  Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH  Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH  Zurich    47.377      8.542
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 17995  27.899  74.179  41.474  6.677  50.869  1.028  103        7.079
# 17996   2.950  47.988  42.235  2.821  35.551  0.644  105       28.734
# 17997  61.347  72.908  46.976  5.763  66.492  0.947  122       21.951
# 17998  40.722  95.152  32.957  5.524  53.193  0.868   95       24.042
# 17999  25.830  30.411  35.317  4.336  66.246  0.848   88        8.529
#
#        humidity  wind_speed
# 17995    52.443       7.452
# 17996    85.678       4.496
# 17997    72.311       9.660
# ...

# %%
file.sample(2) #Random rows
# Out:
#                         timestamp country    city  latitude  longitude  \
# 14418  2025-11-05 12:25:17.554219      PH  Manila    14.600    120.984
# 2066   2025-11-15 20:25:17.554219      ES  Madrid    40.417     -3.704
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# 14418  76.200  124.234  30.889  5.663  70.603  0.902  152       35.745
# 2066   19.645   66.886  36.112  3.298  43.943  0.679   90       27.455
#
#        humidity  wind_speed
# 14418    30.450       3.245
# 2066     77.455       9.734

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    18000 non-null  object
#  1   country      18000 non-null  object
#  2   city         18000 non-null  object
#  3   latitude     18000 non-null  float64
#  4   longitude    18000 non-null  float64
#  5   pm25         18000 non-null  float64
#  6   pm10         18000 non-null  float64
#  7   no2          18000 non-null  float64
#  8   so2          18000 non-null  float64
#  9   o3           18000 non-null  float64
#  10  co           18000 non-null  float64
#  11  aqi          18000 non-null  int64
#  12  temperature  18000 non-null  float64
#  13  humidity     18000 non-null  float64
#  14  wind_speed   18000 non-null  float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
file.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
file.nunique()
# Out:
# timestamp        360
# country           38
# city              50
# latitude          50
# longitude         50
# pm25           15839
# pm10           16332
# no2            15139
# so2             8158
# o3             15275
# co              1376
# aqi              178
# temperature    13930
# humidity       15725
# wind_speed      8058
# dtype: int64

# %%
file.shape
# Out:
# (18000, 15)

# %%
file.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')

# %%
file.dtypes
# Out:
# timestamp       object
# country         object
# city            object
# latitude       float64
# longitude      float64
# pm25           float64
# pm10           float64
# no2            float64
# so2            float64
# o3             float64
# co             float64
# aqi              int64
# temperature    float64
# humidity       float64
# wind_speed     float64
# dtype: object

# %% [markdown]
# # Indexing & Data Selection

# %%
file["country"]
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 17995    CH
# 17996    CH
# 17997    CH
# 17998    CH
# 17999    CH
# Name: country, Length: 18000, dtype: object

# %%
file[["city","aqi"]]
# Out:
#            city  aqi
# 0      New York  108
# 1      New York   90
# 2      New York   84
# 3      New York  158
# 4      New York   97
# ...         ...  ...
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
# 17998    Zurich   95
# 17999    Zurich   88
#
# [18000 rows x 2 columns]

# %%
file.loc[0:5]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
# 5  2025-11-04 23:25:17.554219      US  New York    40.713    -74.006  31.242
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
# ...

# %%
file.loc[0,"latitude"]
# Out:
# np.float64(40.713)

# %%
file.iloc[1]
# Out:
# timestamp      2025-11-04 19:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               32.083
# pm10                               63.043
# no2                                 36.12
# so2                                 4.021
# o3                                 43.536
# co                                  1.075
# aqi                                    90
# temperature                         5.838
# humidity                           80.088
# wind_speed                          8.969
# Name: 1, dtype: object

# %%
file.at[5000,"city"]
# Out:
# 'Nairobi'

# %%
file.iat[1,3]
# Out:
# np.float64(40.713)

# %% [markdown]
# # Filtering & Querying Data

# %%
file[file["aqi"]>200]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 745    2025-11-05 19:25:17.554219      GB    London    51.507     -0.128
# 8941   2025-11-17 07:25:17.554219      JP     Osaka    34.694    135.502
# 12956  2025-11-19 14:25:17.554219      NZ  Auckland   -36.848    174.763
# 14555  2025-11-11 05:25:17.554219      PH    Manila    14.600    120.984
# 17458  2025-11-12 04:25:17.554219      FI  Helsinki    60.170     24.938
# 17529  2025-11-15 03:25:17.554219      FI  Helsinki    60.170     24.938
# 17815  2025-11-12 01:25:17.554219      CH    Zurich    47.377      8.542
#
#           pm25    pm10     no2     so2      o3     co  aqi  temperature  \
# 745    107.144  43.819  13.389   4.601  21.680  0.890  214       19.055
# 8941   102.142  95.204  41.688   7.806  28.951  0.753  204       15.277
# 12956   44.824  66.657  90.019   3.637  41.311  0.849  225       14.872
# 14555  103.023  66.678  43.284   2.167  48.250  0.849  206       11.027
# ...

# %%
file[(file["country"] == "IN") & (file["aqi"] > 200)]
# Out:
# Empty DataFrame
# Columns: [timestamp, country, city, latitude, longitude, pm25, pm10, no2, so2, o3, co, aqi, temperature, humidity, wind_speed]
# Index: []

# %%
file.query("country=='IN' and aqi<200")
# Out:
#                        timestamp country     city  latitude  longitude  \
# 6480  2025-11-04 18:25:17.554219      IN   Mumbai    19.076     72.878
# 6481  2025-11-04 19:25:17.554219      IN   Mumbai    19.076     72.878
# 6482  2025-11-04 20:25:17.554219      IN   Mumbai    19.076     72.878
# 6483  2025-11-04 21:25:17.554219      IN   Mumbai    19.076     72.878
# 6484  2025-11-04 22:25:17.554219      IN   Mumbai    19.076     72.878
# ...                          ...     ...      ...       ...        ...
# 8275  2025-11-19 13:25:17.554219      IN  Chennai    13.083     80.271
# 8276  2025-11-19 14:25:17.554219      IN  Chennai    13.083     80.271
# 8277  2025-11-19 15:25:17.554219      IN  Chennai    13.083     80.271
# 8278  2025-11-19 16:25:17.554219      IN  Chennai    13.083     80.271
# 8279  2025-11-19 17:25:17.554219      IN  Chennai    13.083     80.271
#
#         pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
file.isnull()
# Out:
#        timestamp  country   city  latitude  longitude   pm25   pm10    no2  \
# 0          False    False  False     False      False  False  False  False
# 1          False    False  False     False      False  False  False  False
# 2          False    False  False     False      False  False  False  False
# 3          False    False  False     False      False  False  False  False
# 4          False    False  False     False      False  False  False  False
# ...          ...      ...    ...       ...        ...    ...    ...    ...
# 17995      False    False  False     False      False  False  False  False
# 17996      False    False  False     False      False  False  False  False
# 17997      False    False  False     False      False  False  False  False
# 17998      False    False  False     False      False  False  False  False
# 17999      False    False  False     False      False  False  False  False
#
#          so2     o3     co    aqi  temperature  humidity  wind_speed
# ...

# %%
file.isnull().sum()
# Out:
# timestamp      0
# country        0
# city           0
# latitude       0
# longitude      0
# pm25           0
# pm10           0
# no2            0
# so2            0
# o3             0
# co             0
# aqi            0
# temperature    0
# humidity       0
# wind_speed     0
# dtype: int64

# %%
file.duplicated("aqi")
copy=file.drop_duplicates("country").copy()
copy.count()
# Out:
# timestamp      38
# country        38
# city           38
# latitude       38
# longitude      38
# pm25           38
# pm10           38
# no2            38
# so2            38
# o3             38
# co             38
# aqi            38
# temperature    38
# humidity       38
# wind_speed     38
# dtype: int64

# %% [markdown]
# # String Cleaning

# %%
file
file["country"].str.lower()
file
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...
