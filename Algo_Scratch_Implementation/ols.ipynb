# %% [markdown]
# # Ordinary Lesat Square (OLS)

# %%
import pandas as pd
import numpy as np

# %%
class LinearRegressionOLS:
    def __init__(self):
        self.bias=None
        self.weights=None
    def fit(self,X,y):
        m,n=X.shape
        X_b=np.c_[np.ones((m,2)),X]
        #Normal Equation
        # theta=np.dot(np.linalg.inv(np.dot(X_b.T,X_b)),np.dot(X_b.T,y))
        theta=np.linalg.inv(X_b.T @ X_b)@ X_b.T @ y # @ here defines the dot product

        self.bias=theta[0]
        self.weights=theta[1:]
    def predict (self,X):
        y_pred=self.bias+np.dot(X,self.weights)
        return y_pred

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,6,8,10])
model=LinearRegressionOLS()
model.fit(X,y)
y_pred=model.predict(X)
print(y_pred)
print(model.bias)
print(model.weights)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[23], line 4
#       2 y=np.array([2,4,6,8,10])
#       3 model=LinearRegressionOLS()
# ----> 4 model.fit(X,y)
#       5 y_pred=model.predict(X)
#       6 print(y_pred)
#
# Cell In[22], line 10, in LinearRegressionOLS.fit(self, X, y)
#       7 X_b=np.c_[np.ones((m,2)),X]
#       8 #Normal Equation
#       9 # theta=np.dot(np.linalg.inv(np.dot(X_b.T,X_b)),np.dot(X_b.T,y))
# ---> 10 theta=np.linalg.inv(X_b.T @ X_b)@ X_b.T @ y # @ here defines the dot product
#      12 self.bias=theta[0]
#      13 self.weights=theta[1:]
#
# File ~\Downloads\New folder\Lib\site-packages\numpy\linalg\_linalg.py:669, in inv(a)
#     666 signature = 'D->D' if isComplexType(t) else 'd->d'
#     667 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     668               over='ignore', divide='ignore', under='ignore'):
# --> 669     ainv = _umath_linalg.inv(a, signature=signature)
#     670 return wrap(ainv.astype(result_t, copy=False))
#
# File ~\Downloads\New folder\Lib\site-packages\numpy\linalg\_linalg.py:163, in _raise_linalgerror_singular(err, flag)
#     162 def _raise_linalgerror_singular(err, flag):
# --> 163     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
