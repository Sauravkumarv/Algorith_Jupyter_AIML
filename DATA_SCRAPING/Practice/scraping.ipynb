# %% [markdown]
# # Writting Raw HTML to CSV File

# %%
import requests
import pandas as pd
url="https://www.scrapethissite.com/pages/forms/"
res=requests.get(url)

# %%
if res.status_code==200:
 with open("scrap_data.csv","w") as f:
   df=f.write(res.text)
