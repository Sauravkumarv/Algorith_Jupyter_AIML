# %%
import torch
import torch.nn as nn

# %%
# Input
inputs=torch.tensor([1.0,2.0,3.0])
neuron=nn.Linear(in_feature=3,out_feature=1)

# %%
# Find weigth
neuron.weight

# %%
output=neuron(inputs)
output

# %%
import torch
print("Torch imported")
